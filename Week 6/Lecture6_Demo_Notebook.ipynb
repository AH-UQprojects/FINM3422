# %% [markdown]
# # Lecture 6 – Python & GitHub II
# ## Demonstration Notebook

# %% [markdown]
# ## 1. Environment Info

# %%
import sys, pandas as pd, numpy as np
print(sys.version)
pd.__version__
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]
# '3.0.1'

# %% [markdown]
# ## 2. Imports & Config

# %%
import pandas as pd
import numpy as np
pd.set_option('display.float_format', '{:.4f}'.format)

# %% [markdown]
# ## 3. Paths

# %%
DATA_PATH = '../assessment2_data/benchmarks/aus_eq_bm.csv'

# %% [markdown]
# ## 4. Load and Sanity Checks

# %%
df = pd.DataFrame({'Return': returns}, index=dates)
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 100 entries, 2020-01-31 to 2028-04-30
# Freq: ME
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Return  100 non-null    float64
# dtypes: float64(1)
# memory usage: 1.6 KB
#             Return
# 2020-01-31 -0.0026
# 2020-02-29 -0.0767
# 2020-03-31  0.0176
# 2020-04-30 -0.0266
# 2020-05-31 -0.0225

# %% [markdown]
# ## 5. Transformations

# %%
# Example transformation: monthly alignment
df = df.sort_index().asfreq('ME')
df.head()
# Out:
#             Return
# 2020-01-31 -0.0026
# 2020-02-29 -0.0767
# 2020-03-31  0.0176
# 2020-04-30 -0.0266
# 2020-05-31 -0.0225

# %% [markdown]
# ## 6. Sample Metric Functions

# %%
def annualised_return(r):
    return (1 + r).prod() ** (12/len(r)) - 1

def annualised_vol(r):
    return r.std() * np.sqrt(12)

# %% [markdown]
# ## 7. Visual Checks

# %%
import matplotlib.pyplot as plt
((1+df['Return']).cumprod()).plot(title='Wealth Index'); plt.show()

# %% [markdown]
# ## 8. Summary

# %%
print('Ann Return:', annualised_return(df['Return']))
print('Ann Vol:', annualised_vol(df['Return']))
# Out:
# Ann Return: 0.15229537814248584
# Ann Vol: 0.16672474496438974
