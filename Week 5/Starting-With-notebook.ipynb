# %%
# Imports & config (near the top)
import math, sys
print(sys.version)

# A small calculation cell
angle = math.pi / 4
sine = math.sin(angle)
sine
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]
# 0.7071067811865476

# %% [markdown]
# # Headings & emphasis FINM3422
#
# # Title (H1)
# ## Section (H2)
# **bold** and *italic*

# %% [markdown]
# # Lists & links
#
#
# - Bullet item
# 1. Numbered item
# [Course repo](https://github.com/AH-UQprojects/FINM3422)

# %% [markdown]
# # Inline/code blocks
#
# Use `inline code` for short names.
#
# Inline: $r = \frac{P_t}{P_{t-1}} - 1$

# %% [markdown]
# Block:
# $$
# \text{Sharpe} = \frac{\mathbb{E}[R_p - R_f]}{\sigma_p}
# $$

# %% [markdown]
# # Sample table
#
#
# | Metric   | Value |
# |---------:|------:|
# | Return   |  6.2% |
# | Vol      | 10.5% |

# %%
# Extract values from the table and calculate average
metrics = [0.062, 0.105]  # Return (6.2%) and Vol (10.5%)
average = sum(metrics) / len(metrics)
print(f"Average: {average:.1%}")
