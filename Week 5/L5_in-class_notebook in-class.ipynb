# %% [markdown]
# # FINM3422 – Lecture 5 In‑Class Notebook (Foundations)
# Use this during the lecture. Cells marked **TODO (lecture)** are completed live in class.

# %%
# %pip install --upgrade pip
# %pip install pandas
# %pip install matplotlib
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (25.3)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.7 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
#   WARNING: The scripts pip, pip3 and pip3.14 are installed in '/Library/Frameworks/Python.framework/Versions/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pip-26.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-3.0.1-cp314-cp314-macosx_10_15_x86_64.whl.metadata (79 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.4.3-cp314-cp314-macosx_14_0_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/samunderwood/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/samunderwood/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp314-cp314-macosx_10_15_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 10.2 MB/s  0:00:01ta 0:00:01m
# Downloading numpy-2.4.3-cp314-cp314-macosx_14_0_x86_64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 26.7 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [numpy]  WARNING: The scripts f2py and numpy-config are installed in '/Library/Frameworks/Python.framework/Versions/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.3 pandas-3.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-macosx_10_13_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp314-cp314-macosx_10_15_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-macosx_10_15_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /Users/samunderwood/Library/Python/3.14/lib/python/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp314-cp314-macosx_10_15_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/samunderwood/Library/Python/3.14/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/samunderwood/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-macosx_10_13_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 24.3 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp314-cp314-macosx_10_13_x86_64.whl (292 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp314-cp314-macosx_10_15_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 17.3 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-macosx_10_15_x86_64.whl (66 kB)
# Downloading pillow-12.1.1-cp314-cp314-macosx_10_15_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 24.0 MB/s  0:00:00m0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [fonttools]  WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Library/Frameworks/Python.framework/Versions/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# 0) Sanity check: Python, pandas, matplotlib
print('Hello FINM3422 👋')
import sys, pandas as pd, matplotlib.pyplot as plt
sys.version.split()[0]
# Out:
# Hello FINM3422 👋
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## 1) Load data (prices, monthly)
# We keep a tiny CSV in `data/prices_monthly.csv` with a `Date` column and a few asset columns.

# %%
# TODO (lecture): Run the following code : Create a DataFrame of stock prices for two stocks A and B:
prices = pd.DataFrame({'A':[100,101,103],'B':[100,99,100]}, index=pd.to_datetime(['2020-01-31','2020-02-29','2020-03-31']))
prices.head()

# %%
# TODO (lecture): read the CSV so that Date becomes the index and is parsed as datetime
# Hints: use pd.read_csv('filename.csv', parse_dates=['Date'], index_col='Date')
# Replace the placeholder below.
import pandas as pd
#placeholder for pd.read_csv
prices.head()

# %% [markdown]
# ## 2) Inspect quickly
# Use `.info()`, `.head()`, and `.describe()` to build trust in the table before modelling.

# %%
prices.info()
display(prices.head())
display(prices.describe())

# %% [markdown]
# ## 3) Compute simple returns
# We want fractional monthly returns from prices.

# %%
# TODO (lecture): fill in pct_change to compute returns
# returns = prices.____().dropna()
returns.head()

# %% [markdown]
# ## 4) Ensure monthly labels
# Label the index monthly (no aggregation).

# %%
# TODO (lecture): use asfreq to set a monthly frequency label
# returns = returns.____('ME')
returns.index.freq

# %% [markdown]
# ## 5) Wealth index & one plot
# From returns to an indexed wealth curve (start = 1.0).

# %%
# TODO (lecture): complete the one-liner for wealth index
import matplotlib.pyplot as plt
# wealth = (1 + returns).____().cumprod()
ax = wealth.plot(title='Wealth index (start=1.0)')
ax.set_xlabel('Date'); ax.set_ylabel('Index'); plt.show()

# %% [markdown]
# ## 6) Stretch: handle missing values (choose & document)
# Decide whether to `ffill`, `bfill`, or `dropna`, and *state why*.

# %%
# OPTIONAL TODO (lecture/tutorial): experiment with missing-data handling
returns_clean = returns.dropna()
returns_clean.head()

# %% [markdown]
# ## 7) Save figure (optional)
# Saving outputs makes your work reproducible.

# %%
# OPTIONAL: save plot
import os
os.makedirs('outputs', exist_ok=True)
ax = wealth.plot(title='Wealth index (saved)')
plt.savefig('outputs/wealth_index.png', dpi=150); plt.close()
'Saved to outputs/wealth_index.png'
