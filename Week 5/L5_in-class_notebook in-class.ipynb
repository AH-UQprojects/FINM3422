# %% [markdown]
# # FINM3422 – Lecture 5 In‑Class Notebook (Foundations)
# Use this during the lecture. Cells marked **TODO (lecture)** are completed live in class.

# %%
# %pip install --upgrade pip
# %pip install pandas
# %pip install matplotlib
# Out:
# Requirement already satisfied: pip in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\nisha\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\nisha\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\nisha\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\nisha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\nisha\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\nisha\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 0) Sanity check: Python, pandas, matplotlib
print('Hello FINM3422 👋')
import sys, pandas as pd, matplotlib.pyplot as plt
sys.version.split()[0]
# Out:
# Hello FINM3422 👋
# '3.14.3'

# %% [markdown]
# ## 1) Load data (prices, monthly)
# We keep a tiny CSV in `data/prices_monthly.csv` with a `Date` column and a few asset columns.

# %%
# TODO (lecture): Run the following code : Create a DataFrame of stock prices for two stocks A and B:
prices = pd.DataFrame({'A':[100,101,103],'B':[100,99,100]}, index=pd.to_datetime(['2020-01-31','2020-02-29','2020-03-31']))
prices.head()
# Out:
#               A    B
# 2020-01-31  100  100
# 2020-02-29  101   99
# 2020-03-31  103  100

# %%
# TODO (lecture): read the CSV so that Date becomes the index and is parsed as datetime
# Hints: use pd.read_csv('filename.csv', parse_dates=['Date'], index_col='Date')
# Replace the placeholder below.
import pandas as pd
#placeholder for pd.read_csv
prices.head()
# Out:
#               A    B
# 2020-01-31  100  100
# 2020-02-29  101   99
# 2020-03-31  103  100

# %% [markdown]
# ## 2) Inspect quickly
# Use `.info()`, `.head()`, and `.describe()` to build trust in the table before modelling.

# %%
prices.info()
display(prices.head())
display(prices.describe())
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 3 entries, 2020-01-31 to 2020-03-31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0 bytes
#               A    B
# 2020-01-31  100  100
# 2020-02-29  101   99
# 2020-03-31  103  100
#                 A           B
# count    3.000000    3.000000
# mean   101.333333   99.666667
# std      1.527525    0.577350
# min    100.000000   99.000000
# 25%    100.500000   99.500000
# 50%    101.000000  100.000000
# 75%    102.000000  100.000000
# max    103.000000  100.000000

# %% [markdown]
# ## 3) Compute simple returns
# We want fractional monthly returns from prices.

# %%
# TODO (lecture): fill in pct_change to compute returns
returns = prices.pct_change().dropna()
returns.head()
# Out:
#                    A         B
# 2020-02-29  0.010000 -0.010000
# 2020-03-31  0.019802  0.010101

# %% [markdown]
# ## 4) Ensure monthly labels
# Label the index monthly (no aggregation).

# %%
# TODO (lecture): use asfreq to set a monthly frequency label
# returns = returns.____('ME')
returns.index.freq

# %% [markdown]
# ## 5) Wealth index & one plot
# From returns to an indexed wealth curve (start = 1.0).

# %%
# TODO (lecture): complete the one-liner for wealth index
import matplotlib.pyplot as plt
wealth = (1 + returns).cumprod()
ax = wealth.plot(title='Wealth index (start=1.0)')
ax.set_xlabel('Date'); ax.set_ylabel('Index'); plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 import matplotlib.pyplot as plt
#       3 # wealth = (1 + returns).____().cumprod()
# ----> 4 ax = wealth.plot(title='Wealth index (start=1.0)')
#       5 ax.set_xlabel('Date'); ax.set_ylabel('Index'); plt.show()
#
# NameError: name 'wealth' is not defined

# %% [markdown]
# ## 6) Stretch: handle missing values (choose & document)
# Decide whether to `ffill`, `bfill`, or `dropna`, and *state why*.

# %%
# OPTIONAL TODO (lecture/tutorial): experiment with missing-data handling
returns_clean = returns.dropna()
returns_clean.head()

# %% [markdown]
# ## 7) Save figure (optional)
# Saving outputs makes your work reproducible.

# %%
# OPTIONAL: save plot
import os
os.makedirs('outputs', exist_ok=True)
ax = wealth.plot(title='Wealth index (saved)')
plt.savefig('outputs/wealth_index.png', dpi=150); plt.close()
'Saved to outputs/wealth_index.png'
